# %%
# Dependencies
import pandas as pd
import numpy as np
import requests
import json
import ssl
from sqlalchemy import create_engine, inspect

ssl._create_default_https_context = ssl._create_unverified_context
# Import API key
from config import gkey

# %%
# Import College Football Stadiums file into the stadiums_pd DataFrame
url = 'https://en.wikipedia.org/wiki/List_of_NCAA_Division_I_FBS_football_stadiums'
stadiums_pd = pd.read_html(url)[0]

stadiums_pd = stadiums_pd.drop(columns="Image")

stadiums_pd = stadiums_pd.rename(columns={"Record1": "Record Capacity"})

capacity = stadiums_pd['Capacity'].str.split('[').str[0]

stadiums_pd['Capacity']=capacity
capacity = stadiums_pd['Capacity'].str.split('(').str[0]
stadiums_pd['Capacity']=capacity
record = stadiums_pd['Record Capacity'].str.split('(').str[0]
stadiums_pd['Record Capacity']=record
record = stadiums_pd['Record Capacity'].str.split('[').str[0]
stadiums_pd['Record Capacity']=record
built = stadiums_pd['Built'].str.split('[').str[0]
stadiums_pd['Built']=built
stadiums_pd
# Out:
#                                                Stadium         City State  \
# 0                               Aggie Memorial Stadium   Las Cruces    NM
# 1                                            Alamodome  San Antonio    TX
# 2               Alaska Airlines Field at Husky Stadium      Seattle    WA
# 3                                   Albertsons Stadium        Boise    ID
# 4                                    Allegiant Stadium     Paradise    NV
# ..                                                 ...          ...   ...
# 125  Veterans Memorial Stadium at Larry Blakeney Field         Troy    AL
# 126                                      Waldo Stadium    Kalamazoo    MI
# 127                      Warren McGuirk Alumni Stadium       Hadley    MA
# 128    Wayne Day Family Field at Carter–Finley Stadium      Raleigh    NC
# 129                             Williams-Brice Stadium     Columbia    SC
#
#                  Team     Conference Capacity Record Capacity Built  \
# 0    New Mexico State    Independent   30,343          32,993  1978
# 1                UTSA          C-USA    65000          56,743  1993
# 2          Washington         Pac-12   70,083          76,125  1920
# 3         Boise State  Mountain West   36,387          36,864  1970
# 4                UNLV  Mountain West    65000             NaN  2020
# ..                ...            ...      ...             ...   ...
# 125              Troy       Sun Belt    30402          29,013  1950
# 126  Western Michigan            MAC   30,200          36,361  1939
# 127             UMass    Independent   17,000          20,000  1965
# 128          NC State            ACC   57,583          57,583  1966
# 129    South Carolina            SEC   77,559          85,199  1934
#
#       Expanded 2                   Surface
# 0        2005[1]       S5-M Synthetic Turf
# 1            NaN                SportField
# 2           2013                 FieldTurf
# 3        2012[3]                Smurf Turf
# 4            NaN                 FieldTurf
# ..           ...                       ...
# 125  2003 & 2018                  ProGrass
# 126    2003[153]                 FieldTurf
# 127         2014                 FieldTurf
# 128         2006  Tifway 419 Bermuda Grass
# 129    1996[156]                     Grass
#
# [130 rows x 10 columns]

# %%
# Add columns for lat, lng
# Hint: Be sure to specify "" as the initial value for each column.

stadiums_pd['Lat'] = ""
stadiums_pd['Lng'] = ""

stadiums_ordered_pd = stadiums_pd[["Stadium","Lat","Lng","City","State","Team","Conference","Capacity","Record Capacity","Built","Surface"]]
stadiums_ordered_pd
# Out:
#                                                Stadium Lat Lng         City  \
# 0                               Aggie Memorial Stadium           Las Cruces
# 1                                            Alamodome          San Antonio
# 2               Alaska Airlines Field at Husky Stadium              Seattle
# 3                                   Albertsons Stadium                Boise
# 4                                    Allegiant Stadium             Paradise
# ..                                                 ...  ..  ..          ...
# 125  Veterans Memorial Stadium at Larry Blakeney Field                 Troy
# 126                                      Waldo Stadium            Kalamazoo
# 127                      Warren McGuirk Alumni Stadium               Hadley
# 128    Wayne Day Family Field at Carter–Finley Stadium              Raleigh
# 129                             Williams-Brice Stadium             Columbia
#
#     State              Team     Conference Capacity Record Capacity Built  \
# 0      NM  New Mexico State    Independent   30,343          32,993  1978
# 1      TX              UTSA          C-USA    65000          56,743  1993
# 2      WA        Washington         Pac-12   70,083          76,125  1920
# 3      ID       Boise State  Mountain West   36,387          36,864  1970
# 4      NV              UNLV  Mountain West    65000             NaN  2020
# ..    ...               ...            ...      ...             ...   ...
# 125    AL              Troy       Sun Belt    30402          29,013  1950
# 126    MI  Western Michigan            MAC   30,200          36,361  1939
# 127    MA             UMass    Independent   17,000          20,000  1965
# 128    NC          NC State            ACC   57,583          57,583  1966
# 129    SC    South Carolina            SEC   77,559          85,199  1934
#
#                       Surface
# 0         S5-M Synthetic Turf
# 1                  SportField
# 2                   FieldTurf
# 3                  Smurf Turf
# 4                   FieldTurf
# ..                        ...
# 125                  ProGrass
# 126                 FieldTurf
# 127                 FieldTurf
# 128  Tifway 419 Bermuda Grass
# 129                     Grass
#
# [130 rows x 11 columns]

# %%
params = {
    'key': gkey
}
from pprint import pprint

for index, row in stadiums_ordered_pd.iterrows():
    
    target_city = row['Stadium']
    
    base_url = f"https://maps.googleapis.com/maps/api/geocode/json?address={target_city}&key={gkey}"
    
    lat = row['Lat']
    lng = row['Lng']

    # add keyword to params dict
    params['location'] = f'{lat},{lng}'
    
    # assemble 

    response = requests.get(base_url, params=params).json() 
    
    try:
        stadiums_ordered_pd.loc[index, 'Latitude'] = response['results'][0]['geometry']['location']['lat']
        stadiums_ordered_pd.loc[index, 'Longitude'] = response['results'][0]['geometry']['location']['lng'] 
    
    except:
        print(target_city)
    
stadiums_ordered_pd
# Out:
#                                                Stadium Lat Lng         City  \
# 0                               Aggie Memorial Stadium           Las Cruces
# 1                                            Alamodome          San Antonio
# 2               Alaska Airlines Field at Husky Stadium              Seattle
# 3                                   Albertsons Stadium                Boise
# 4                                    Allegiant Stadium             Paradise
# ..                                                 ...  ..  ..          ...
# 125  Veterans Memorial Stadium at Larry Blakeney Field                 Troy
# 126                                      Waldo Stadium            Kalamazoo
# 127                      Warren McGuirk Alumni Stadium               Hadley
# 128    Wayne Day Family Field at Carter–Finley Stadium              Raleigh
# 129                             Williams-Brice Stadium             Columbia
#
#     State              Team     Conference Capacity Record Capacity Built  \
# 0      NM  New Mexico State    Independent   30,343          32,993  1978
# 1      TX              UTSA          C-USA    65000          56,743  1993
# 2      WA        Washington         Pac-12   70,083          76,125  1920
# 3      ID       Boise State  Mountain West   36,387          36,864  1970
# 4      NV              UNLV  Mountain West    65000             NaN  2020
# ..    ...               ...            ...      ...             ...   ...
# 125    AL              Troy       Sun Belt    30402          29,013  1950
# 126    MI  Western Michigan            MAC   30,200          36,361  1939
# 127    MA             UMass    Independent   17,000          20,000  1965
# 128    NC          NC State            ACC   57,583          57,583  1966
# 129    SC    South Carolina            SEC   77,559          85,199  1934
#
#                       Surface   Latitude   Longitude
# 0         S5-M Synthetic Turf  32.279486 -106.741713
# 1                  SportField  29.416983  -98.478814
# 2                   FieldTurf  47.650350 -122.301611
# 3                  Smurf Turf  43.602844 -116.195866
# 4                   FieldTurf  36.090866 -115.183322
# ..                        ...        ...         ...
# 125                  ProGrass  31.799556  -85.951833
# 126                 FieldTurf  42.285756  -85.601090
# 127                 FieldTurf  42.377271  -72.536040
# 128  Tifway 419 Bermuda Grass  35.800800  -78.719566
# 129                     Grass  33.973088  -81.019185
#
# [130 rows x 13 columns]

# %%
stadiums_cleaned_df = stadiums_ordered_pd[["Stadium", "Latitude", "Longitude", "City", "State", "Team", "Conference", "Capacity", "Record Capacity", "Built", "Surface"]]

stadiums_cleaned_df
# Out:
#                                                Stadium   Latitude   Longitude  \
# 0                               Aggie Memorial Stadium  32.279486 -106.741713
# 1                                            Alamodome  29.416983  -98.478814
# 2               Alaska Airlines Field at Husky Stadium  47.650350 -122.301611
# 3                                   Albertsons Stadium  43.602844 -116.195866
# 4                                    Allegiant Stadium  36.090866 -115.183322
# ..                                                 ...        ...         ...
# 125  Veterans Memorial Stadium at Larry Blakeney Field  31.799556  -85.951833
# 126                                      Waldo Stadium  42.285756  -85.601090
# 127                      Warren McGuirk Alumni Stadium  42.377271  -72.536040
# 128    Wayne Day Family Field at Carter–Finley Stadium  35.800800  -78.719566
# 129                             Williams-Brice Stadium  33.973088  -81.019185
#
#             City State              Team     Conference Capacity  \
# 0     Las Cruces    NM  New Mexico State    Independent   30,343
# 1    San Antonio    TX              UTSA          C-USA    65000
# 2        Seattle    WA        Washington         Pac-12   70,083
# 3          Boise    ID       Boise State  Mountain West   36,387
# 4       Paradise    NV              UNLV  Mountain West    65000
# ..           ...   ...               ...            ...      ...
# 125         Troy    AL              Troy       Sun Belt    30402
# 126    Kalamazoo    MI  Western Michigan            MAC   30,200
# 127       Hadley    MA             UMass    Independent   17,000
# 128      Raleigh    NC          NC State            ACC   57,583
# 129     Columbia    SC    South Carolina            SEC   77,559
#
#     Record Capacity Built                   Surface
# 0            32,993  1978       S5-M Synthetic Turf
# 1            56,743  1993                SportField
# 2            76,125  1920                 FieldTurf
# 3            36,864  1970                Smurf Turf
# 4               NaN  2020                 FieldTurf
# ..              ...   ...                       ...
# 125          29,013  1950                  ProGrass
# 126          36,361  1939                 FieldTurf
# 127          20,000  1965                 FieldTurf
# 128          57,583  1966  Tifway 419 Bermuda Grass
# 129          85,199  1934                     Grass
#
# [130 rows x 11 columns]

# %%
url = 'https://en.wikipedia.org/wiki/NCAA_Division_I_FBS_football_win-loss_records'
win_loss_record= pd.read_html(url)[2]
win_loss_record
# Out:
#               Team  Won  Lost  Tied   Pct.  Years  Total Games     Conference
# 0     Ohio State 1  931   327    53  0.730    130         1311        Big Ten
# 1        Alabama 2  929   331    43  0.729    125         1303            SEC
# 2     Notre Dame 3  918   328    42  0.729    130         1288    Independent
# 3      Boise State  465   172     2  0.729     52          639  Mountain West
# 4         Michigan  964   350    36  0.727    140         1350        Big Ten
# ..             ...  ...   ...   ...    ...    ...          ...            ...
# 125        UNLV 11  236   364     4  0.394     52          604  Mountain West
# 126     Kent State  353   570    28  0.386     97          951            MAC
# 127            FIU   79   143     0  0.356     18          222          C-USA
# 128      Charlotte   34    62     0  0.354      9           96          C-USA
# 129  Georgia State   42    87     0  0.326     10          129       Sun Belt
#
# [130 rows x 8 columns]

# %%
#create sqlite database and connect to it
database_path = "college_football_db.sqlite"
engine = create_engine(f"sqlite:///{database_path}")
conn = engine.connect()

# %%
# store dataframes into database
stadiums_cleaned_df.to_sql('stadiums', conn, if_exists='replace')
win_loss_record.to_sql('win_loss_record', conn, if_exists='replace')

# %%
# view tables in database
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['stadiums', 'win_loss_record']

# %%
#close database connection
conn.close()
